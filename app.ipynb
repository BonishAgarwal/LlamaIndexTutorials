# %%
! pip install llama-index llama-hub
# Out:
# Collecting llama-index
#   Downloading llama_index-0.9.24-py3-none-any.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 4.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting llama-hub
#   Downloading llama_hub-0.0.65-py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nltk<4.0.0,>=3.8.1
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting typing-inspect>=0.8.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting dataclasses-json
#   Using cached dataclasses_json-0.6.3-py3-none-any.whl (28 kB)
# Collecting fsspec>=2023.5.0
#   Using cached fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.2
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting SQLAlchemy[asyncio]>=1.4.49
#   Downloading SQLAlchemy-2.0.25-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.1 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Collecting aiohttp<4.0.0,>=3.8.6
#   Using cached aiohttp-3.9.1-cp310-cp310-macosx_11_0_arm64.whl (386 kB)
# Collecting openai>=1.1.0
#   Using cached openai-1.6.1-py3-none-any.whl (225 kB)
# Collecting typing-extensions>=4.5.0
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting tiktoken>=0.3.3
#   Using cached tiktoken-0.5.2-cp310-cp310-macosx_11_0_arm64.whl (953 kB)
# Collecting tenacity<9.0.0,>=8.2.0
#   Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting httpx
#   Using cached httpx-0.26.0-py3-none-any.whl (75 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./llama-venv/lib/python3.10/site-packages (from llama-index) (1.5.8)
# Collecting numpy
#   Downloading numpy-1.26.3-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting deprecated>=1.2.9.3
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting pandas
#   Using cached pandas-2.1.4-cp310-cp310-macosx_11_0_arm64.whl (10.9 MB)
# Collecting requests>=2.31.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting pyaml<24.0.0,>=23.9.7
#   Downloading pyaml-23.12.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: psutil in ./llama-venv/lib/python3.10/site-packages (from llama-hub) (5.9.7)
# Collecting retrying
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting html2text
#   Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Collecting async-timeout<5.0,>=4.0
#   Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.4.1-cp310-cp310-macosx_11_0_arm64.whl (52 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.4-cp310-cp310-macosx_11_0_arm64.whl (29 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.9.4-cp310-cp310-macosx_11_0_arm64.whl (79 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting wrapt<2,>=1.10
#   Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Collecting tqdm
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Collecting joblib
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting click
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting regex>=2021.8.3
#   Using cached regex-2023.12.25-cp310-cp310-macosx_11_0_arm64.whl (291 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting sniffio
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting anyio<5,>=3.5.0
#   Using cached anyio-4.2.0-py3-none-any.whl (85 kB)
# Collecting pydantic<3,>=1.9.0
#   Using cached pydantic-2.5.3-py3-none-any.whl (381 kB)
# Collecting idna
#   Using cached idna-3.6-py3-none-any.whl (61 kB)
# Collecting certifi
#   Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.2-py3-none-any.whl (76 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting PyYAML
#   Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl (169 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.3-cp310-cp310-macosx_11_0_universal2.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.1/270.1 kB 4.8 MB/s eta 0:00:000:00:01
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached marshmallow-3.20.1-py3-none-any.whl (49 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./llama-venv/lib/python3.10/site-packages (from pandas->llama-index) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Requirement already satisfied: six>=1.7.0 in ./llama-venv/lib/python3.10/site-packages (from retrying->llama-hub) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./llama-venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in ./llama-venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index) (23.2)
# Collecting pydantic-core==2.14.6
#   Using cached pydantic_core-2.14.6-cp310-cp310-macosx_11_0_arm64.whl (1.7 MB)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Installing collected packages: pytz, wrapt, urllib3, tzdata, typing-extensions, tqdm, tenacity, soupsieve, sniffio, retrying, regex, PyYAML, numpy, mypy-extensions, multidict, marshmallow, joblib, idna, html2text, h11, greenlet, fsspec, frozenlist, distro, click, charset-normalizer, certifi, attrs, async-timeout, annotated-types, yarl, typing-inspect, SQLAlchemy, requests, pydantic-core, pyaml, pandas, nltk, httpcore, deprecated, beautifulsoup4, anyio, aiosignal, tiktoken, pydantic, httpx, dataclasses-json, aiohttp, openai, llama-index, llama-hub
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.25 aiohttp-3.9.1 aiosignal-1.3.1 annotated-types-0.6.0 anyio-4.2.0 async-timeout-4.0.3 attrs-23.2.0 beautifulsoup4-4.12.2 certifi-2023.11.17 charset-normalizer-3.3.2 click-8.1.7 dataclasses-json-0.6.3 deprecated-1.2.14 distro-1.9.0 frozenlist-1.4.1 fsspec-2023.12.2 greenlet-3.0.3 h11-0.14.0 html2text-2020.1.16 httpcore-1.0.2 httpx-0.26.0 idna-3.6 joblib-1.3.2 llama-hub-0.0.65 llama-index-0.9.24 marshmallow-3.20.1 multidict-6.0.4 mypy-extensions-1.0.0 nltk-3.8.1 numpy-1.26.3 openai-1.6.1 pandas-2.1.4 pyaml-23.12.0 pydantic-2.5.3 pydantic-core-2.14.6 pytz-2023.3.post1 regex-2023.12.25 requests-2.31.0 retrying-1.3.4 sniffio-1.3.0 soupsieve-2.5 tenacity-8.2.3 tiktoken-0.5.2 tqdm-4.66.1 typing-extensions-4.9.0 typing-inspect-0.9.0 tzdata-2023.4 urllib3-2.1.0 wrapt-1.16.0 yarl-1.9.4
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in ./llama-venv/lib/python3.10/site-packages (from wikipedia) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in ./llama-venv/lib/python3.10/site-packages (from wikipedia) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./llama-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./llama-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./llama-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2023.11.17)
# Requirement already satisfied: idna<4,>=2.5 in ./llama-venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.6)
# Requirement already satisfied: soupsieve>1.2 in ./llama-venv/lib/python3.10/site-packages (from beautifulsoup4->wikipedia) (2.5)
# Installing collected packages: wikipedia
#   DEPRECATION: wikipedia is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for wikipedia ... done
# Successfully installed wikipedia-1.4.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
from llama_index.readers import WikipediaReader

loader = WikipediaReader()
documents = loader.load_data(
    pages=["OpenAI", "Sam Altman", "Mira Murati", "Emmett Shear"],
    auto_suggest=False,
)

# %%
print(documents)
# Out:
# [Document(id_='633cac01-3951-4f5f-88ac-a252d0ee99df', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='85b236a544653f2a43cb9b2116a8f7ac0b6c71d45237d0b917e6a66e22f2785b', text='OpenAI is a U.S. artificial intelligence (AI) research organization founded in December 2015, researching artificial intelligence with the declared intention of developing "safe and beneficial" artificial general intelligence, which it defines as "highly autonomous systems that outperform humans at most economically valuable work".\nAs one of the leading organizations of the AI Spring, it has developed several large language models, advanced image generation models, and previously, also open-source models. Its release of ChatGPT has been credited with starting the artificial intelligence spring.The organization consists of the non-profit OpenAI, Inc. registered in Delaware and its for-profit subsidiary OpenAI Global, LLC.  It was founded by Ilya Sutskever, Greg Brockman, Trevor Blackwell, Vicki Cheung, Andrej Karpathy, Durk Kingma, Jessica Livingston, John Schulman, Pamela Vagata, and Wojciech Zaremba, with Sam Altman and Elon Musk serving as the initial board members. Microsoft provided OpenAI Global LLC with a $1 billion investment in 2019 and a $10 billion investment in 2023, with a significant portion of the investment in the form of compute resources on Microsoft\'s Azure cloud service.On November 17, 2023, the board removed Altman as CEO, while Brockman was removed as chairman and then resigned as president. Four days later, both returned after negotiations with the board, and most of the board members resigned. The new initial board included former Salesforce co-CEO Bret Taylor as chairmanand Microsoft with a non-voting board seat.\n\n\n== History ==\n\n\n=== 2015–2018: Non-profit beginnings ===\nIn December 2015, Sam Altman, Greg Brockman, Reid Hoffman, Jessica Livingston, Peter Thiel, Elon Musk, Amazon Web Services (AWS), Infosys, and YC Research announced the formation of OpenAI and pledged over $1 billion to the venture. The actual collected total amount of contributions was only $130 million until 2019. According to an investigation led by TechCrunch, Musk was its largest donor while YC Research did not contribute anything at all. The organization stated it would "freely collaborate" with other institutions and researchers by making its patents and research open to the public. OpenAI is headquartered at the Pioneer Building in Mission District, San Francisco.According to Wired, Brockman met with Yoshua Bengio, one of the "founding fathers" of deep learning, and drew up a list of the "best researchers in the field". Brockman was able to hire nine of them as the first employees in December 2015. In 2016, OpenAI paid corporate-level (rather than nonprofit-level) salaries, but did not pay AI researchers salaries comparable to those of Facebook or Google.Microsoft\'s Peter Lee stated that the cost of a top AI researcher exceeds the cost of a top NFL quarterback prospect. OpenAI\'s potential and mission drew these researchers to the firm; a Google employee said he was willing to leave Google for OpenAI "partly because of the very strong group of people and, to a very large extent, because of its mission." Brockman stated that "the best thing that I could imagine doing was moving humanity closer to building real AI in a safe way." OpenAI co-founder Wojciech Zaremba stated that he turned down "borderline crazy" offers of two to three times his market value to join OpenAI instead.In April 2016, OpenAI released a public beta of "OpenAI Gym", its platform for reinforcement learning research. Nvidia gifted its first DGX-1 supercomputer to OpenAI in August 2016 to help it train larger and more complex AI models with the capability of reducing processing time from six days to two hours. In December 2016, OpenAI released "Universe", a software platform for measuring and training an AI\'s ge ...

# %%
# do sentence splitting on the first piece of text
from llama_index.node_parser import SentenceSplitter

# %%
sentence_splitter = SentenceSplitter(chunk_size=1024)

print(sentence_splitter)
# Out:
# include_metadata=True include_prev_next_rel=True callback_manager=<llama_index.callbacks.base.CallbackManager object at 0x2846b1120> id_func=<function default_id_func at 0x129b800d0> chunk_size=1024 chunk_overlap=200 separator=' ' paragraph_separator='\n\n\n' secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?'

# %%
openai_node = sentence_splitter.get_nodes_from_documents([documents[0]])[0]
print(openai_node)
# Out:
# Node ID: 5cd643f0-9894-4734-acfc-573b95cb9c52
# Text: OpenAI is a U.S. artificial intelligence (AI) research
# organization founded in December 2015, researching artificial
# intelligence with the declared intention of developing "safe and
# beneficial" artificial general intelligence, which it defines as
# "highly autonomous systems that outperform humans at most economically
# valuable work". As one of the...
